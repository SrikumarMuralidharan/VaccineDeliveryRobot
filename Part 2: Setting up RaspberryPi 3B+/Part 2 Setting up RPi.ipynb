# %% [markdown]
# # Setting up RaspberryPi 3B+
# ## Srikumar Muralidharan <br>

# %% [markdown]
# Part 1: Importing sanitycheck.py and checking if that runs with no errors: <br>

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import imutils
import cv2

print('imported properly')
# Out:
# imported properly

# %% [markdown]
# Part 2: Connecting Pi wirelessly and Putty in to it. Check for VNC functionality: <br>
# To ensure Putty-in is working:<br>
# ![Puttyimage.png](attachment:Puttyimage.png) <br>
# To ensure VNC is working with Putty <br>

# %% [markdown]
# ![VNC-putty_image.png](attachment:VNC-putty_image.png)

# %% [markdown]
# Part 3: Use Filezilla to Send files over SFTP to my PI: <br>
# ![Filezilla.png](attachment:Filezilla.png)

# %% [markdown]
# Part 4: Checking if Raspistill and raspvid function correctly: <br>
# ![Testpic.png](attachment:Testpic.png)

# %% [markdown]
# Part 5: Video using Raspberry Pi <br>
# https://youtu.be/2PB2nGNSFEE

# %% [markdown]
# # #dontbeshyabouttoys #toysareus
